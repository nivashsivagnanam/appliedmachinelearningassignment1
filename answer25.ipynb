# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Manually enter the dataset
data = np.array([
    [0.0000000e+00, 2.2250403e-01],
    [2.0000000e-02, -8.1385327e-02],
    [4.0000000e-02, 2.1861593e-01],
    [6.0000000e-02, 1.9221327e-01],
    [8.0000000e-02, -1.5396746e-01],
    [1.0000000e-01, 2.5389041e-01],
    [1.2000000e-01, 1.9386472e-01],
    [1.4000000e-01, -1.1101360e-01],
    [1.6000000e-01, -9.7178693e-02],
    [1.8000000e-01, -1.8628026e-01],
    [2.0000000e-01, -3.1633282e-01],
    [2.2000000e-01, -1.9062228e-01],
    [2.4000000e-01, -5.0903698e-01],
    [2.6000000e-01, -8.9357587e-03],
    [2.8000000e-01, -5.2546428e-01],
    [3.0000000e-01, -5.2623656e-01],
    [3.2000000e-01, -3.8455134e-01],
    [3.4000000e-01, -6.3280120e-01],
    [3.6000000e-01, -7.0824349e-01],
    [3.8000000e-01, -8.9758549e-01],
    [4.0000000e-01, -7.1163108e-01],
    [4.2000000e-01, -1.0744028e+00],
    [4.4000000e-01, -6.9807967e-01],
    [4.6000000e-01, -5.4701499e-01],
    [4.8000000e-01, -1.0377604e+00],
    [5.0000000e-01, -7.5228020e-01],
    [5.2000000e-01, -6.9426279e-01],
    [5.4000000e-01, -1.2816263e+00],
    [5.6000000e-01, -1.2654610e+00],
    [5.8000000e-01, -8.7394539e-01],
    [6.0000000e-01, -1.0755391e+00],
    [6.2000000e-01, -8.6140347e-01],
    [6.4000000e-01, -8.3655973e-01],
    [6.6000000e-01, -8.5402302e-01],
    [6.8000000e-01, -7.3152617e-01],
    [7.0000000e-01, -8.4550271e-01],
    [7.2000000e-01, -7.2721402e-01],
    [7.4000000e-01, -1.1885933e+00],
    [7.6000000e-01, -9.3140306e-01],
    [7.8000000e-01, -9.3482842e-01],
    [8.0000000e-01, -1.1971238e+00],
    [8.2000000e-01, -7.9454626e-01],
    [8.4000000e-01, -1.0239888e+00],
    [8.6000000e-01, -4.9345822e-01],
    [8.8000000e-01, -8.9853120e-01],
    [9.0000000e-01, -5.9016419e-01],
    [9.2000000e-01, -6.0796959e-01],
    [9.4000000e-01, -7.8981323e-01],
    [9.6000000e-01, -9.9101052e-01],
    [9.8000000e-01, -5.1817237e-01],
    [1.0000000e+00, -6.5611724e-01],
])

# Extract x and y values
x = data[:, 0]
y = data[:, 1]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Print regression results
print(f"Best-fit line equation: y = {slope:.6f}x + {intercept:.6f}")
print(f"R-squared value: {r_value**2:.6f}")

# Plot the data points
plt.scatter(x, y, label="Data Points", color="blue")

# Plot the best-fit line
plt.plot(x, slope * x + intercept, color="red", label="Best-Fit Line")

# Labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Linear Regression Fit")
plt.legend()
plt.grid()

# Show plot
plt.show()
# Out:
# Best-fit line equation: y = -0.993329x + -0.105934
# R-squared value: 0.505033

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data points
data = np.array([
    [0.0, 2.2250403e-01],
    [0.02, -8.1385327e-02],
    [0.04, 2.1861593e-01],
    [0.06, 1.9221327e-01],
    [0.08, -1.5396746e-01],
    [0.10, 2.5389041e-01],
    [0.12, 1.9386472e-01],
    [0.14, -1.1101360e-01],
    [0.16, -9.7178693e-02],
    [0.18, -1.8628026e-01],
    [0.20, -3.1633282e-01],
    [0.22, -1.9062228e-01],
    [0.24, -5.0903698e-01],
    [0.26, -8.9357587e-03],
    [0.28, -5.2546428e-01],
    [0.30, -5.2623656e-01],
    [0.32, -3.8455134e-01],
    [0.34, -6.3280120e-01],
    [0.36, -7.0824349e-01],
    [0.38, -8.9758549e-01],
    [0.40, -7.1163108e-01],
    [0.42, -1.0744028e+00],
    [0.44, -6.9807967e-01],
    [0.46, -5.4701499e-01],
    [0.48, -1.0377604e+00],
    [0.50, -7.5228020e-01],
    [0.52, -6.9426279e-01],
    [0.54, -1.2816263e+00],
    [0.56, -1.2654610e+00],
    [0.58, -8.7394539e-01],
    [0.60, -1.0755391e+00],
    [0.62, -8.6140347e-01],
    [0.64, -8.3655973e-01],
    [0.66, -8.5402302e-01],
    [0.68, -7.3152617e-01],
    [0.70, -8.4550271e-01],
    [0.72, -7.2721402e-01],
    [0.74, -1.1885933e+00],
    [0.76, -9.3140306e-01],
    [0.78, -9.3482842e-01],
    [0.80, -1.1971238e+00],
    [0.82, -7.9454626e-01],
    [0.84, -1.0239888e+00],
    [0.86, -4.9345822e-01],
    [0.88, -8.9853120e-01],
    [0.90, -5.9016419e-01],
    [0.92, -6.0796959e-01],
    [0.94, -7.8981323e-01],
    [0.96, -9.9101052e-01],
    [0.98, -5.1817237e-01],
    [1.00, -6.5611724e-01]
])

# Extract x and y values
x = data[:, 0]
y = data[:, 1]

# Fit polynomial of degree 2, 3, and 4
poly2 = np.polyfit(x, y, 2)
poly3 = np.polyfit(x, y, 3)
poly4 = np.polyfit(x, y, 4)

# Generate predictions
x_fit = np.linspace(min(x), max(x), 100)
y_fit2 = np.polyval(poly2, x_fit)
y_fit3 = np.polyval(poly3, x_fit)
y_fit4 = np.polyval(poly4, x_fit)

# Compute Mean Squared Error (MSE) for each polynomial
y_pred2 = np.polyval(poly2, x)
y_pred3 = np.polyval(poly3, x)
y_pred4 = np.polyval(poly4, x)

mse2 = np.mean((y - y_pred2) ** 2)
mse3 = np.mean((y - y_pred3) ** 2)
mse4 = np.mean((y - y_pred4) ** 2)

# Plot the data and fitted polynomials
plt.figure(figsize=(10, 6))
plt.scatter(x, y, label="Data", color="black", marker="o")
plt.plot(x_fit, y_fit2, label=f"Degree 2 (MSE={mse2:.4f})", linestyle="--")
plt.plot(x_fit, y_fit3, label=f"Degree 3 (MSE={mse3:.4f})", linestyle="-.")
plt.plot(x_fit, y_fit4, label=f"Degree 4 (MSE={mse4:.4f})", linestyle=":")

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Polynomial Regression Fits")
plt.legend()
plt.grid(True)
plt.show()

# Output errors for comparison
mse2, mse3, mse4
# Out:
# (np.float64(0.036179001439891355),
#  np.float64(0.03525278493278306),
#  np.float64(0.03269048800303598))
